# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepikasutharshini/Project/blob/master/pandasprofilingcapabilties-eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import pandas_profiling
import numpy as np

# %%
#load and prepare example dataset
df = pd.read_csv("https://data.nasa.gov/api/views/gh4g-9sfh/rows.csv?accessType=DOWNLOAD",parse_dates=['year'],encoding='UTF-8')
df.dtypes
df.describe()
# Out:
#                  id      mass (g)        reclat       reclong       States  \
# count  45716.000000  4.558500e+04  38401.000000  38401.000000  1659.000000
# mean   26889.735104  1.327808e+04    -39.122580     61.074319    17.337553
# std    16860.683030  5.749889e+05     46.378511     80.647298    10.410888
# min        1.000000  0.000000e+00    -87.366670   -165.433330     1.000000
# 25%    12688.750000  7.200000e+00    -76.714240      0.000000     9.000000
# 50%    24261.500000  3.260000e+01    -71.500000     35.666670    15.000000
# 75%    40656.750000  2.026000e+02      0.000000    157.166670    23.000000
# max    57458.000000  6.000000e+07     81.166670    354.473330    51.000000
#
#           Counties
# count  1659.000000
# mean   1353.331525
# std     994.089259
# min       5.000000
# 25%     482.000000
# 50%    1195.000000
# 75%    2113.000000
# max    3210.000000

# %%
#note : Pandas not supoort dates before 1880,so weignore these for this analysis
df['year'] = pd.to_datetime(df['year'],errors='coerce')
#example : constant variable
df['source']="NASA"
#example:Boolean variable
df['boolean'] = np.random.choice([True,False],df.shape[0])
#example mixed with base type
df['mixed'] = np.random.choice([1,"A"],df.shape[0])

#example : highly correlated variable
df['reclat_city'] = df['reclat'] + np.random.normal(scale=5,size=len(df))
#example : duplicate observation
duplicates_to_add = pd.DataFrame(df.iloc[0:10])
duplicates_to_add[u'name']=duplicates_to_add[u'name'] +"copy"
df = df.append(duplicates_to_add,ignore_index=True)

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
pfr = pandas_profiling.ProfileReport(df)
pfr.to_file("/tmp/example.html")
#print existing ProfileReport object line
pfr
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
